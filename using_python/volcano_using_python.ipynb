# %%
# %pip install sanbomics

# %%
from sanbomics.plots import volcano
import pandas as pd

# %%
df = pd.read_csv('C:/RNA_Seq_Analysis/data/pydeseq_out.csv') # output from pyDeSEQ2
df
# Out:
#                Geneid     baseMean  log2FoldChange     lfcSE      stat  \
# 0     ENSG00000267792    36.577737        0.702140  0.377913  1.857942
# 1     ENSG00000116017   216.374437        0.024935  0.279795  0.089118
# 2     ENSG00000064932  1003.818007        0.077024  0.149345  0.515744
# 3     ENSG00000099864   204.286437        1.285579  1.014923  1.266677
# 4     ENSG00000125912  2297.088603        0.190592  0.099768  1.910347
# ...               ...          ...             ...       ...       ...
# 1093  ENSG00000267577    48.604995        0.261493  0.372593  0.701818
# 1094  ENSG00000129990    16.884222        1.372733  0.611599  2.244498
# 1095  ENSG00000080031    55.244759        0.286896  0.669016  0.428832
# 1096  ENSG00000105426  1959.649271        0.336462  0.231963  1.450500
# 1097  ENSG00000121410    10.246270        0.205620  0.456596  0.450333
#
#         pvalue      padj      symbol
# 0     0.063177  0.324423    WBP1LP11
# 1     0.928988  0.978197      ARID3A
# ...

# %%
volcano(df) # volcano('deseq_out.csv') also works
# default thresholds: padj 0.05, log fold change 0.75 and top 5 up & down regulated genes

# %%
volcano(df, pval_thresh=0.01, log2fc_thresh=2, to_label=4)
